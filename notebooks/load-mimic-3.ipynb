# %%
import json 
import pandas as pd

# load payload
with open("../data/payload_mimic3.json", "r") as f:
    loaded_payload = json.load(f)

loaded_df = pd.DataFrame(loaded_payload)

# %%
loaded_df
# Out:
#      subject_id  hadm_id      admittime      dischtime admission_type  \
# 0         10006   142345  6147695340000  6148458900000      EMERGENCY
# 1         10011   105331  4942420320000  4943617140000      EMERGENCY
# 2         10013   165520  4915294560000  4915523580000      EMERGENCY
# 3         10017   199207  5661335940000  5662032120000      EMERGENCY
# 4         10019   177759  6102074580000  6102129600000      EMERGENCY
# ..          ...      ...            ...            ...            ...
# 124       44083   198330  4493893500000  4494761400000      EMERGENCY
# 125       44154   174245  6575459340000  6575507100000      EMERGENCY
# 126       44212   163189  4856508840000  4859620260000      EMERGENCY
# 127       44222   192189  6644271300000  6644379600000      EMERGENCY
# 128       44228   103379  6341512440000  6342343200000      EMERGENCY
#
#     insurance language marital_status               ethnicity gender  ...  \
# 0    Medicare     None      SEPARATED  BLACK/AFRICAN AMERICAN      F  ...
# 1     Private     None         SINGLE   UNKNOWN/NOT SPECIFIED      F  ...
# 2    Medicare     None           None   UNKNOWN/NOT SPECIFIED      F  ...
# 3    Medicare     None       DIVORCED                   WHITE      F  ...
# 4    Medicare     None       DIVORCED                   WHITE      M  ...
# ..        ...      ...            ...                     ...    ...  ...
# 124   Private     ENGL         SINGLE                   WHITE      M  ...
# 125  Medicare     ENGL        MARRIED                   WHITE      M  ...
# 126  Medicare     ENGL         SINGLE  BLACK/AFRICAN AMERICAN      F  ...
# 127  Medicare     ENGL         SINGLE                   WHITE      M  ...
# 128   Private     ENGL         SINGLE                   WHITE      F  ...
#
#     creatinina hemoglobina  potassio  sodio  creatinina_uom  hemoglobina_uom  \
# 0          5.3        11.1       4.6  138.0           mg/dL             g/dL
# 1          0.7         9.8       4.0  138.0           mg/dL             g/dL
# 2        276.0         8.8       4.1  138.0            IU/L             g/dL
# 3          0.4         8.8       4.0  140.0           mg/dL             g/dL
# 4          4.0        12.5       5.2  136.0           mg/dL             g/dL
# ..         ...         ...       ...    ...             ...              ...
# 124        0.6         8.8       4.1  138.0           mg/dL             g/dL
# 125        0.9        14.0       4.5  142.0           mg/dL             g/dL
# 126        1.9         7.9       3.6  135.0           mg/dL             g/dL
# 127        1.2        12.9       4.2  135.0           mg/dL             g/dL
# 128        0.7         9.7       3.3  142.0           mg/dL             g/dL
#
#     potassio_uom sodio_uom notas_24h_resumo  \
# 0          mEq/L     mEq/L             None
# 1          mEq/L     mEq/L             None
# 2          mEq/L     mEq/L             None
# 3          mEq/L     mEq/L             None
# 4          mEq/L     mEq/L             None
# ..           ...       ...              ...
# 124        mEq/L     mEq/L             None
# 125        mEq/L     mEq/L             None
# 126        mEq/L     mEq/L             None
# 127        mEq/L     mEq/L             None
# 128        mEq/L     mEq/L             None
#
#                                            prescricoes
# 0    [{'drug': 'Sodium Chloride 0.9%  Flush', 'drug...
# 1                                                   []
# 2    [{'drug': 'Furosemide', 'drug_type': 'MAIN', '...
# 3    [{'drug': 'Hydromorphone', 'drug_type': 'MAIN'...
# 4    [{'drug': 'Propofol', 'drug_type': 'MAIN', 'do...
# ..                                                 ...
# 124  [{'drug': 'Potassium Chloride', 'drug_type': '...
# 125  [{'drug': 'Pneumococcal Vac Polyvalent', 'drug...
# 126  [{'drug': 'Sodium Chloride 0.9%  Flush', 'drug...
# 127  [{'drug': 'Bisacodyl', 'drug_type': 'MAIN', 'd...
# 128  [{'drug': 'Influenza Virus Vaccine', 'drug_typ...
#
# [129 rows x 22 columns]

# %%
loaded_df.columns
# Out:
# Index(['subject_id', 'hadm_id', 'admittime', 'dischtime', 'admission_type',
#        'insurance', 'language', 'marital_status', 'ethnicity', 'gender',
#        'age_estimada', 'diag_list', 'creatinina', 'hemoglobina', 'potassio',
#        'sodio', 'creatinina_uom', 'hemoglobina_uom', 'potassio_uom',
#        'sodio_uom', 'notas_24h_resumo', 'prescricoes'],
#       dtype='object')
