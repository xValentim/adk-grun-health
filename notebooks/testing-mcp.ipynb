# %%
from langchain_mcp_adapters.client import MultiServerMCPClient


client = MultiServerMCPClient(
    {
        "MyServer": {
            "url": "http://127.0.0.1:8001/mcp",
            "transport": "streamable_http",
        }
    }
)
tools = await client.get_tools()
router = {
    t.name: t for t in tools
}

# %%
tools
# Out:
# [StructuredTool(name='add', description='Adds two numbers.', args_schema={'properties': {'a': {'type': 'integer'}, 'b': {'type': 'integer'}}, 'required': ['a', 'b'], 'type': 'object'}, metadata={'_meta': {'_fastmcp': {'tags': []}}}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001CFEE7BB910>),
#  StructuredTool(name='pizza_salami_price', description='Returns that Pizza Salami at Bella Vista costs 10€.', args_schema={'properties': {}, 'type': 'object'}, metadata={'_meta': {'_fastmcp': {'tags': []}}}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001CFEE8B83A0>),
#  StructuredTool(name='current_year', description='Returns the current year.', args_schema={'properties': {}, 'type': 'object'}, metadata={'_meta': {'_fastmcp': {'tags': []}}}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001CFEE8B8820>),
#  StructuredTool(name='greet', description='Greets a person with their name.', args_schema={'properties': {'name': {'type': 'string'}}, 'required': ['name'], 'type': 'object'}, metadata={'_meta': {'_fastmcp': {'tags': []}}}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001CFEE8B84C0>),
#  StructuredTool(name='qualify_lead', description='Qualifica um lead e retorna apenas o essencial.\nArguments:\n    lead_data: str - Dados do lead em formato de texto.\nOutputs:\n    dict - Dicionário com validação, score e recomendação.', args_schema={'properties': {'lead_data': {'type': 'string'}}, 'required': ['lead_data'], 'type': 'object'}, metadata={'_meta': {'_fastmcp': {'tags': []}}}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001CFEE8B8160>),
#  StructuredTool(name='qualify_essay', description='Qualifica uma redação e retorna apenas o essencial. Essa análise é feita para ajudar um aluno a melhorar sua redação.\nArguments:\n    essay_text: str - Texto da redação a ser analisada.\nOutputs:\n    dict - Dicionário com análise de conteúdo, análise estrutural e relatório sintetizado.', args_schema={'properties': {'essay_text': {'type': 'string'}}, 'required': ['essay_text'], 'type': 'object'}, metadata={'_meta': {'_fastmcp': {'tags': []}}}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001CFEE8B8280>),
#  StructuredTool(name='search_agent', description='Executa o agente de busca e retorna apenas o essencial. O LLM pega a query do usuário, usa uma tool de busca no google e retorna os resultados trazendo informações relevantes interpretadas pelo modelo.\nArguments:\n    query: str - Consulta de busca em formato de texto.\nOutputs:\n    dict - Dicionário com os resultados da busca.', args_schema={'properties': {'query': {'type': 'string'}}, 'required': ['query'], 'type': 'object'}, metadata={'_meta': {'_fastmcp': {'tags': []}}}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001CFEE8B8670>)]
